# %%
import os
import numpy as np
import pandas as pd

# %% [markdown]
# ## UCF_dataset

# %%
BENCHMARK = True
csv_dir = '/data1-6tb/jom/EzFit_models/evaluation_videos/UCF_dataset/outputs/'

# %%
# # model_types = ['kps_stacked', 'kps_seq', 'kps_single', 'image_single', 'ViViT', 'video_sequence']
# model_types = ['kps_seq']
# exercise_list = ['pushup', 'squat', 'jumping-jack']
# for model in model_types:
#     temp = os.path.join(csv_dir, f'{model}_hard_vote_UCF_dataset.csv')
#     print(f'===== {model} =====')
#     df = pd.read_csv(temp)
#     print('Overall OBO:', df['obo'].mean())
#     for exercise in exercise_list:
#         print(f'OBO of {exercise}:', df[df['exercise']==exercise]['obo'].mean())
#     print()

# model_types = ['kps_stacked', 'kps_seq', 'kps_single', 'image_single', 'ViViT', 'video_sequence']
model_types = ['kps_seq']
exercise_list = ['pushup', 'squat', 'jumping-jack']
for model in model_types:
    temp = os.path.join(csv_dir, f'{model}_hard_vote_UCF_dataset.csv')
    if BENCHMARK:
        temp = os.path.join(csv_dir, f'{model}_hard_vote_UCF_dataset_BM.csv')
    print(f'===== {model} =====')
    print('==================')
    df = pd.read_csv(temp)
    # not include jumping-jack_extra (full side view)
    print('Overall OBO:', df[~df['file_name'].str.contains('jumping-jack_extra')]['obo'].mean())
    for exercise in exercise_list:
        print(f'----->{exercise}<-----')
        if exercise == 'jumping-jack':
            res_df = df[df['exercise']==exercise][~df['file_name'].str.contains('extra')]
            res_df['5-classes-view'] = res_df['5-classes-view'].str.strip()
            print(f'OBO of {exercise}:', res_df['obo'].mean())
        else:
            res_df = df[df['exercise']==exercise]
            print(f'OBO of {exercise}:', res_df['obo'].mean())
        
        ### labels analysis ###
        # view
        for view in res_df['5-classes-view'].unique():
            temp = res_df[res_df['5-classes-view']==view]
            print(f'===View: {view}===')
            print(f'amount: {len(temp)} | percentage: {len(temp)/len(res_df)}')
            print(f"OBO: {temp['obo'].mean()}")
            print()
        # position
        temp = res_df[res_df['position']=='center']
        print(f'===Position: center===')
        print(f'amount: {len(temp)} | percentage: {len(temp)/len(res_df)}')
        print(f"OBO: {temp['obo'].mean()}")
        print()
        temp = res_df[res_df['position']!='center']
        print(f'===Position: Non-center===')
        print(f'amount: {len(temp)} | percentage: {len(temp)/len(res_df)}')
        print(f"OBO: {temp['obo'].mean()}")
        print()
        # distance
        for dist in res_df['distance'].unique():
            temp = res_df[res_df['distance']==dist]
            print(f'===Distance: {dist}===')
            print(f'amount: {len(temp)} | percentage: {len(temp)/len(res_df)}')
            print(f"OBO: {temp['obo'].mean()}")
            print()
        # gender
        for gender in res_df['gender'].unique():
            temp = res_df[res_df['gender']==gender]
            print(f'===Gender: {gender}===')
            print(f'amount: {len(temp)} | percentage: {len(temp)/len(res_df)}')
            print(f"OBO: {temp['obo'].mean()}")
            print()
        # indoor/outdoor
        for area in res_df['indoor/outdoor'].unique():
            temp = res_df[res_df['indoor/outdoor']==area]
            print(f'===Indoor/Outdoor: {area}===')
            print(f'amount: {len(temp)} | percentage: {len(temp)/len(res_df)}')
            print(f"OBO: {temp['obo'].mean()}")
            print()
        
        print('-------------------')
    print()
# Out:
# ===== kps_seq =====
# ==================
# Overall OBO: 0.9196428571428571
# ----->pushup<-----
# OBO of pushup: 0.8725490196078431
# ===View: side===
# amount: 49 | percentage: 0.4803921568627451
# OBO: 1.0
#
# ===View: right-tilted===
# amount: 18 | percentage: 0.17647058823529413
# OBO: 0.7222222222222222
#
# ===View: left-tilted===
# amount: 7 | percentage: 0.06862745098039216
# OBO: 1.0
#
# ===View: back===
# amount: 4 | percentage: 0.0392156862745098
# OBO: 0.75
#
# ===View: front===
# amount: 24 | percentage: 0.23529411764705882
# OBO: 0.7083333333333334
#
# ===Position: center===
# amount: 102 | percentage: 1.0
# OBO: 0.8725490196078431
#
# ===Position: Non-center===
# amount: 0 | percentage: 0.0
# OBO: nan
#
# ===Distance: fit===
# amount: 87 | percentage: 0.8529411764705882
# OBO: 0.8620689655172413
#
# ===Distance: close===
# amount: 15 | percentage: 0.14705882352941177
# OBO: 0.9333333333333333
#
# ===Gender: male===
# amount: 74 | percentage: 0.7254901960784313
# OBO: 0.8513513513513513
#
# ===Gender: female===
# amount: 28 | percentage: 0.27450980392156865
# OBO: 0.9285714285714286
#
# ===Indoor/Outdoor: indoor===
# amount: 90 | percentage: 0.8823529411764706
# OBO: 0.9
#
# ===Indoor/Outdoor: outdoor===
# amount: 12 | percentage: 0.11764705882352941
# OBO: 0.6666666666666666
#
# -------------------
# ----->squat<-----
# OBO of squat: 0.9910714285714286
# ===View: side===
# amount: 69 | percentage: 0.6160714285714286
# OBO: 0.9855072463768116
#
# ===View: right-tilted===
# amount: 12 | percentage: 0.10714285714285714
# OBO: 1.0
#
# ===View: front===
# amount: 23 | percentage: 0.20535714285714285
# OBO: 1.0
#
# ===View: left-tilted===
# amount: 8 | percentage: 0.07142857142857142
# OBO: 1.0
#
# ===Position: center===
# amount: 106 | percentage: 0.9464285714285714
# OBO: 0.9905660377358491
#
# ===Position: Non-center===
# amount: 6 | percentage: 0.05357142857142857
# OBO: 1.0
#
# ===Distance: fit===
# amount: 76 | percentage: 0.6785714285714286
# OBO: 0.9868421052631579
#
# ===Distance: close===
# amount: 25 | percentage: 0.22321428571428573
# OBO: 1.0
#
# ===Distance: far===
# amount: 11 | percentage: 0.09821428571428571
# OBO: 1.0
#
# ===Gender: male===
# amount: 93 | percentage: 0.8303571428571429
# OBO: 0.989247311827957
#
# ===Gender: female===
# amount: 19 | percentage: 0.16964285714285715
# OBO: 1.0
#
# ===Indoor/Outdoor: indoor===
# amount: 102 | percentage: 0.9107142857142857
# OBO: 0.9901960784313726
#
# ===Indoor/Outdoor: outdoor===
# amount: 10 | percentage: 0.08928571428571429
# OBO: 1.0
#
# -------------------
# ----->jumping-jack<-----
# OBO of jumping-jack: 0.8934426229508197
# ===View: front===
# amount: 101 | percentage: 0.8278688524590164
# OBO: 0.9603960396039604
#
# ===View: side===
# amount: 9 | percentage: 0.07377049180327869
# OBO: 0.4444444444444444
#
# ===View: left-tilted===
# amount: 11 | percentage: 0.09016393442622951
# OBO: 0.6363636363636364
#
# ===View: back===
# amount: 1 | percentage: 0.00819672131147541
# OBO: 1.0
#
# ===Position: center===
# amount: 118 | percentage: 0.9672131147540983
# OBO: 0.923728813559322
#
# ===Position: Non-center===
# amount: 4 | percentage: 0.03278688524590164
# OBO: 0.0
#
# ===Distance: fit===
# amount: 91 | percentage: 0.7459016393442623
# OBO: 0.9340659340659341
#
# ===Distance: close===
# amount: 27 | percentage: 0.22131147540983606
# OBO: 0.7407407407407407
#
# ===Distance: far===
# amount: 4 | percentage: 0.03278688524590164
# OBO: 1.0
#
# ===Gender: female===
# amount: 59 | percentage: 0.48360655737704916
# OBO: 0.9491525423728814
#
# ===Gender: male===
# amount: 63 | percentage: 0.5163934426229508
# OBO: 0.8412698412698413
#
# ===Indoor/Outdoor: indoor===
# amount: 63 | percentage: 0.5163934426229508
# OBO: 0.8888888888888888
#
# ===Indoor/Outdoor: outdoor===
# amount: 59 | percentage: 0.48360655737704916
# OBO: 0.8983050847457628
#
# -------------------
# /tmp/ipykernel_31808/958379359.py:28: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   res_df = df[df['exercise']==exercise][~df['file_name'].str.contains('extra')]

# %% [markdown]
# ## EzFit_dataset

# %%
BENCHMARK = True
csv_dir = '/data1-6tb/jom/EzFit_models/evaluation_videos/EzFit_dataset/outputs/'

# %%
# model_types = ['kps_stacked', 'kps_seq', 'kps_single', 'image_single', 'ViViT', 'video_sequence']
model_types = ['kps_seq']
exercise_list = ['pushup', 'squat', 'jumping-jack', 'leg-raise', 'half-burpee']
for model in model_types:
    temp = os.path.join(csv_dir, f'{model}_hard_vote_EzFit_dataset.csv')
    if BENCHMARK:
        temp = os.path.join(csv_dir, f'{model}_hard_vote_EzFit_dataset_BM.csv')
    print(f'===== {model} =====')
    print('==================')
    df = pd.read_csv(temp)
    # not include jumping-jack_extra (full side view)
    print('Overall OBO:', df[~df['file_name'].str.contains('jumping-jack_extra')]['obo'].mean())
    for exercise in exercise_list:
        print(f'----->{exercise}<-----')
        if exercise == 'jumping-jack':
            res_df = df[df['exercise']==exercise][~df['file_name'].str.contains('extra')]
            res_df['5-classes-view'] = res_df['5-classes-view'].str.strip()
            print(f'OBO of {exercise}:', res_df['obo'].mean())
        else:
            res_df = df[df['exercise']==exercise]
            print(f'OBO of {exercise}:', res_df['obo'].mean())
        
        ### labels analysis ###
        # view
        for view in res_df['5-classes-view'].unique():
            temp = res_df[res_df['5-classes-view']==view]
            print(f'===View: {view}===')
            print(f'amount: {len(temp)} | percentage: {len(temp)/len(res_df)}')
            print(f"OBO: {temp['obo'].mean()}")
            print()
        # position
        temp = res_df[res_df['position']=='center']
        print(f'===Position: center===')
        print(f'amount: {len(temp)} | percentage: {len(temp)/len(res_df)}')
        print(f"OBO: {temp['obo'].mean()}")
        print()
        temp = res_df[res_df['position']!='center']
        print(f'===Position: Non-center===')
        print(f'amount: {len(temp)} | percentage: {len(temp)/len(res_df)}')
        print(f"OBO: {temp['obo'].mean()}")
        print()
        # distance
        for dist in res_df['distance'].unique():
            temp = res_df[res_df['distance']==dist]
            print(f'===Distance: {dist}===')
            print(f'amount: {len(temp)} | percentage: {len(temp)/len(res_df)}')
            print(f"OBO: {temp['obo'].mean()}")
            print()
        print('-------------------')
    print()
# Out:
# ===== kps_seq =====
# ==================
# Overall OBO: 0.9848484848484849
# ----->pushup<-----
# OBO of pushup: 1.0
# ===View: side===
# amount: 6 | percentage: 0.46153846153846156
# OBO: 1.0
#
# ===View: right-tilted===
# amount: 2 | percentage: 0.15384615384615385
# OBO: 1.0
#
# ===View: front===
# amount: 2 | percentage: 0.15384615384615385
# OBO: 1.0
#
# ===View: left-tilted===
# amount: 3 | percentage: 0.23076923076923078
# OBO: 1.0
#
# ===Position: center===
# amount: 10 | percentage: 0.7692307692307693
# OBO: 1.0
#
# ===Position: Non-center===
# amount: 3 | percentage: 0.23076923076923078
# OBO: 1.0
#
# ===Distance: fit===
# amount: 8 | percentage: 0.6153846153846154
# OBO: 1.0
#
# ===Distance: far===
# amount: 3 | percentage: 0.23076923076923078
# OBO: 1.0
#
# ===Distance: close===
# amount: 2 | percentage: 0.15384615384615385
# OBO: 1.0
#
# -------------------
# ----->squat<-----
# OBO of squat: 1.0
# ===View: side===
# amount: 6 | percentage: 0.5
# OBO: 1.0
#
# ===View: left-tilted===
# amount: 2 | percentage: 0.16666666666666666
# OBO: 1.0
#
# ===View: right-tilted===
# amount: 3 | percentage: 0.25
# OBO: 1.0
#
# ===View: front===
# amount: 1 | percentage: 0.08333333333333333
# OBO: 1.0
#
# ===Position: center===
# amount: 12 | percentage: 1.0
# OBO: 1.0
#
# ===Position: Non-center===
# amount: 0 | percentage: 0.0
# OBO: nan
#
# ===Distance: fit===
# amount: 9 | percentage: 0.75
# OBO: 1.0
#
# ===Distance: close===
# amount: 1 | percentage: 0.08333333333333333
# OBO: 1.0
#
# ===Distance: far===
# amount: 2 | percentage: 0.16666666666666666
# OBO: 1.0
#
# -------------------
# ----->jumping-jack<-----
# OBO of jumping-jack: 1.0
# ===View: front===
# amount: 7 | percentage: 0.5
# OBO: 1.0
#
# ===View: left-tilted===
# amount: 2 | percentage: 0.14285714285714285
# OBO: 1.0
#
# ===View: right-tilted===
# amount: 3 | percentage: 0.21428571428571427
# OBO: 1.0
#
# ===View: side===
# amount: 2 | percentage: 0.14285714285714285
# OBO: 1.0
#
# ===Position: center===
# amount: 10 | percentage: 0.7142857142857143
# OBO: 1.0
#
# ===Position: Non-center===
# amount: 4 | percentage: 0.2857142857142857
# OBO: 1.0
#
# ===Distance: fit===
# amount: 8 | percentage: 0.5714285714285714
# OBO: 1.0
#
# ===Distance: far===
# amount: 4 | percentage: 0.2857142857142857
# OBO: 1.0
#
# ===Distance: close===
# amount: 2 | percentage: 0.14285714285714285
# OBO: 1.0
#
# -------------------
# ----->leg-raise<-----
# OBO of leg-raise: 1.0
# ===View: side===
# amount: 8 | percentage: 0.5714285714285714
# OBO: 1.0
#
# ===View: back===
# amount: 3 | percentage: 0.21428571428571427
# OBO: 1.0
#
# ===View: right-tilted===
# amount: 1 | percentage: 0.07142857142857142
# OBO: 1.0
#
# ===View: left-tilted===
# amount: 2 | percentage: 0.14285714285714285
# OBO: 1.0
#
# ===Position: center===
# amount: 14 | percentage: 1.0
# OBO: 1.0
#
# ===Position: Non-center===
# amount: 0 | percentage: 0.0
# OBO: nan
#
# ===Distance: fit===
# amount: 12 | percentage: 0.8571428571428571
# OBO: 1.0
#
# ===Distance: far===
# amount: 2 | percentage: 0.14285714285714285
# OBO: 1.0
#
# -------------------
# ----->half-burpee<-----
# OBO of half-burpee: 0.9230769230769231
# ===View: side===
# amount: 7 | percentage: 0.5384615384615384
# OBO: 0.8571428571428571
#
# ===View: right-tilted===
# amount: 2 | percentage: 0.15384615384615385
# OBO: 1.0
#
# ===View: back===
# amount: 2 | percentage: 0.15384615384615385
# OBO: 1.0
#
# ===View: left-tilted===
# amount: 2 | percentage: 0.15384615384615385
# OBO: 1.0
#
# ===Position: center===
# amount: 8 | percentage: 0.6153846153846154
# OBO: 0.875
#
# ===Position: Non-center===
# amount: 5 | percentage: 0.38461538461538464
# OBO: 1.0
#
# ===Distance: fit===
# amount: 10 | percentage: 0.7692307692307693
# OBO: 1.0
#
# ===Distance: far===
# amount: 3 | percentage: 0.23076923076923078
# OBO: 0.6666666666666666
#
# -------------------
# /tmp/ipykernel_29491/3256759345.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   res_df = df[df['exercise']==exercise][~df['file_name'].str.contains('extra')]

# %%
df
# Out:
#               file_name  rep     exercise 3-classes-view 5-classes-view  \
# 0   half-burpee_1_1.mp4   11  half-burpee           side           side
# 1   half-burpee_1_2.mp4    9  half-burpee           side           side
# 2   half-burpee_2_1.mp4    3  half-burpee           side           side
# 3   half-burpee_2_2.mp4    4  half-burpee           side   right-tilted
# 4   half-burpee_2_3.mp4    3  half-burpee           back           back
# ..                  ...  ...          ...            ...            ...
# 63        squat_3_1.mp4    8        squat           side           side
# 64        squat_3_2.mp4    6        squat          front          front
# 65        squat_3_3.mp4    7        squat           side   right-tilted
# 66        squat_3_4.mp4    5        squat           side           side
# 67        squat_3_5.mp4    5        squat           side           side
#
#    position distance  pred  obo
# 0    center      fit    11    1
# 1    center      fit     9    1
# 2    center      fit     3    1
# 3     right      fit     4    1
# 4    center      fit     3    1
# ..      ...      ...   ...  ...
# 63   center      fit     8    1
# 64   center      fit     6    1
# 65   center      far     2    0
# 66   center      far     5    1
# 67   center      fit     5    1
#
# [68 rows x 9 columns]
